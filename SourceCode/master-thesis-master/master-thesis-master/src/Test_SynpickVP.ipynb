# %%
import os

import torch
import lib.visualizations as visualizations

from data import SynpickVP, SynpickInstances
from data.load_data import build_data_loader

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = SynpickInstances(
        split="valid",
        num_frames=6,
        seq_step=2,         # default
        max_overlap=0.25,   # default
        img_size=(64, 112)
    )
# Out:
# SynpickVP test-sequences have 50 frames. Your num_frames = 6 will be overridden
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 31293/31293 [00:00<00:00, 35668.54it/s]

# %%
loader = build_data_loader(dataset, batch_size=8, shuffle=False)

# %%
instance, data = next(iter(loader))
masks = data["masks"]

# %%
masks.shape
# Out:
# torch.Size([8, 6, 14, 1, 64, 112])

# %%
_ = visualizations.visualize_sequence(masks[2, 0], n_cols=10, add_axis=False, n_channels=1, cmap="gray_r")

# %%
masks_rgb = visualizations.one_hot_instances_to_rgb(masks, num_channels=14)

# %%
_ = visualizations.visualize_sequence(masks_rgb[2])

# %%
# Out:
# torch.Size([8, 6, 1, 64, 112])
